# %%
import requests
import json
import pandas as pd

# %%
link = 'https://www.mercadolivre.com.br/celular-samsung-galaxy-a56-5g-256gb-8gb-ram-preto/p/MLB47104353#polycard_client=search-nordic&search_layout=stack&position=1&type=product&tracking_id=574b629b-e170-4ddd-89c7-80cbb61f6ae9&wid=MLB5646288396&sid=search'

# %% [markdown]
# ![](../static/foto_link_celular.png)

# %%
with open('../access_token.json', 'r') as file:
    access_token = json.load(file)['access_token']

# %%
header = {
    'Authorization':  f'Bearer {access_token}'
}

# %%
params = {
    'status': 'active',
    'site_id': 'MLB',
    'q': 'samsung galaxy a56',
    'limit': 200,
}

products_response = requests.get(url='https://api.mercadolibre.com/products/search', headers=header, params=params)

# %%
products_data = products_response.json()
print(json.dumps(products_data, indent=4))
# Out:
# {
#     "keywords": "samsung galaxy a56",
#     "paging": {
#         "total": 200,
#         "limit": 200,
#         "offset": 0
#     },
#     "results": [
#         {
#             "id": "MLB52144330",
#             "date_created": "2025-07-08T22:52:06Z",
#             "catalog_product_id": "MLB52144330",
#             "pdp_types": [],
#             "status": "active",
#             "domain_id": "MLB-CELLPHONES",
#             "settings": {
#                 "listing_strategy": "catalog_required",
#                 "exclusive": false,
#                 "content": "fixed"
#             },
#             "name": "Samsung Galaxy A56 128gb 8 RAM preto",
#             "main_features": [],
#             "attributes": [
#                 {
#                     "id": "BRAND",
#                     "name": "Marca",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "LINE",
#                     "name": "Linha",
#                     "value_id": "322977",
#                     "value_name": "Galaxy A"
#                 },
#                 {
#                     "id": "MODEL",
#                     "name": "Modelo",
#                     "value_id": "28156286",
#                     "value_name": "A56"
#                 },
#                 {
#                     "id": "IS_DUAL_SIM",
#                     "name": "\u00c9 Dual SIM",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "COLOR",
#                     "name": "Cor",
#                     "value_id": "52049",
#                     "value_name": "Preto"
#                 },
#                 {
#                     "id": "INTERNAL_MEMORY",
#                     "name": "Mem\u00f3ria interna",
#                     "value_id": "84611",
#                     "value_name": "128 GB"
#                 },
#                 {
#                     "id": "RAM",
#                     "name": "Mem\u00f3ria RAM",
#                     "value_id": "579564",
#                     "value_name": "8 GB"
#                 },
#                 {
#                     "id": "MAIN_COLOR",
#                     "name": "Cor principal",
#                     "value_id": "2450295",
#                     "value_name": "Preto"
#                 },
#                 {
#                     "id": "SIM_CARD_SLOTS_NUMBER",
#                     "name": "Quantidade de ranhuras para cart\u00e3o SIM",
#                     "value_id": "2087812",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "OPERATING_SYSTEM_NAME",
#                     "name": "Nome do sistema operacional",
#                     "value_id": "7403813",
#                     "value_name": "Android"
#                 },
#                 {
#                     "id": "MOBILE_NETWORK",
#                     "name": "Rede m\u00f3vel",
#                     "value_id": "7472027",
#                     "value_name": "5G"
#                 },
#                 {
#                     "id": "PROCESSOR_MODEL",
#                     "name": "Modelo do processador",
#                     "value_id": "19270414",
#                     "value_name": "OCTA-CORE"
#                 },
#                 {
#                     "id": "CELLPHONES_ANATEL_HOMOLOGATION_NUMBER",
#                     "name": "N\u00famero de homologa\u00e7\u00e3o da Anatel",
#                     "value_id": "48639515",
#                     "value_name": "107622400953"
#                 }
#             ],
#             "pictures": [
#                 {
#                     "id": "789853-MLA95389851723_102025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_789853-MLA95389851723_102025-F.jpg"
#                 }
#             ],
#             "parent_id": "MLB48925518",
#             "children_ids": [],
#             "quality_type": "COMPLETE",
#             "priority": "MEDIUM",
#             "last_updated": "2025-10-21T11:40:37Z",
#             "type": "PRODUCT",
#             "keywords": "Samsung Galaxy A56 128gb 8 RAM preto",
#             "site_id": "MLB",
#             "variations": [],
#             "buying_mode": "",
#             "channels": [],
#             "description": ""
#         },
#         {
#             "id": "MLB48925520",
#             "date_created": "2025-04-23T14:06:49Z",
#             "catalog_product_id": "MLB48925520",
#             "pdp_types": [],
#             "status": "active",
#             "domain_id": "MLB-CELLPHONES",
#             "settings": {
#                 "listing_strategy": "catalog_required",
#                 "exclusive": false,
#                 "content": "fixed"
#             },
#             "name": "Samsung Galaxy A56 128gb 8 RAM rosa",
#             "main_features": [],
#             "attributes": [
#                 {
#                     "id": "BRAND",
#                     "name": "Marca",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "LINE",
#                     "name": "Linha",
#                     "value_id": "322977",
#                     "value_name": "Galaxy A"
#                 },
#                 {
#                     "id": "MODEL",
#                     "name": "Modelo",
#                     "value_id": "28156286",
#                     "value_name": "A56"
#                 },
#                 {
#                     "id": "IS_DUAL_SIM",
#                     "name": "\u00c9 Dual SIM",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "COLOR",
#                     "name": "Cor",
#                     "value_id": "52045",
#                     "value_name": "Rosa-p\u00e1lido"
#                 },
#                 {
#                     "id": "INTERNAL_MEMORY",
#                     "name": "Mem\u00f3ria interna",
#                     "value_id": "84611",
#                     "value_name": "128 GB"
#                 },
#                 {
#                     "id": "RAM",
#                     "name": "Mem\u00f3ria RAM",
#                     "value_id": "579564",
#                     "value_name": "8 GB"
#                 },
#                 {
#                     "id": "MAIN_COLOR",
#                     "name": "Cor principal",
#                     "value_id": "2450280",
#                     "value_name": "Rosa-claro"
#                 },
#                 {
#                     "id": "DETAILED_MODEL",
#                     "name": "Modelo detalhado",
#                     "value_id": "52221319",
#                     "value_name": "A56"
#                 },
#                 {
#                     "id": "SIM_CARD_SLOTS_NUMBER",
#                     "name": "Quantidade de ranhuras para cart\u00e3o SIM",
#                     "value_id": "2087812",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "OPERATING_SYSTEM_NAME",
#                     "name": "Nome do sistema operacional",
#                     "value_id": "7403813",
#                     "value_name": "Android"
#                 },
#                 {
#                     "id": "MOBILE_NETWORK",
#                     "name": "Rede m\u00f3vel",
#                     "value_id": "7472027",
#                     "value_name": "5G"
#                 },
#                 {
#                     "id": "PROCESSOR_MODEL",
#                     "name": "Modelo do processador",
#                     "value_id": "18543163",
#                     "value_name": "Octa Core"
#                 },
#                 {
#                     "id": "MANUFACTURER",
#                     "name": "Fabricante",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "CELLPHONES_ANATEL_HOMOLOGATION_NUMBER",
#                     "name": "N\u00famero de homologa\u00e7\u00e3o da Anatel",
#                     "value_id": "48639515",
#                     "value_name": "107622400953"
#                 }
#             ],
#             "pictures": [
#                 {
#                     "id": "753403-MLA83995119083_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_753403-MLA83995119083_042025-F.jpg"
#                 },
#                 {
#                     "id": "953425-MLA84205307945_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_953425-MLA84205307945_042025-F.jpg"
#                 },
#                 {
#                     "id": "636457-MLA84205317699_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_636457-MLA84205317699_042025-F.jpg"
#                 },
#                 {
#                     "id": "841925-MLA84205317731_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_841925-MLA84205317731_042025-F.jpg"
#                 },
#                 {
#                     "id": "952112-MLA84205385939_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_952112-MLA84205385939_042025-F.jpg"
#                 },
#                 {
#                     "id": "740049-MLA84205356773_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_740049-MLA84205356773_042025-F.jpg"
#                 },
#                 {
#                     "id": "673140-MLA84205307913_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_673140-MLA84205307913_042025-F.jpg"
#                 }
#             ],
#             "parent_id": "MLB48925518",
#             "children_ids": [],
#             "quality_type": "COMPLETE",
#             "priority": "MEDIUM",
#             "last_updated": "2025-10-21T12:17:50Z",
#             "type": "PRODUCT",
#             "keywords": "Samsung Galaxy A56 128gb 8 RAM rosa",
#             "site_id": "MLB",
#             "variations": [],
#             "buying_mode": "",
#             "channels": [],
#             "description": ""
#         },
#         {
#             "id": "MLB48927251",
#             "date_created": "2025-04-23T17:26:54Z",
#             "catalog_product_id": "MLB48927251",
#             "pdp_types": [],
#             "status": "active",
#             "domain_id": "MLB-CELLPHONES",
#             "settings": {
#                 "listing_strategy": "catalog_required",
#                 "exclusive": false,
#                 "content": "fixed"
#             },
#             "name": "Celular Samsung Galaxy A56 128gb 8 Ram Grey",
#             "main_features": [],
#             "attributes": [
#                 {
#                     "id": "BRAND",
#                     "name": "Marca",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "LINE",
#                     "name": "Linha",
#                     "value_id": "322977",
#                     "value_name": "Galaxy A"
#                 },
#                 {
#                     "id": "MODEL",
#                     "name": "Modelo",
#                     "value_id": "28156286",
#                     "value_name": "A56"
#                 },
#                 {
#                     "id": "IS_DUAL_SIM",
#                     "name": "\u00c9 Dual SIM",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "COLOR",
#                     "name": "Cor",
#                     "value_id": "283165",
#                     "value_name": "Cinza"
#                 },
#                 {
#                     "id": "INTERNAL_MEMORY",
#                     "name": "Mem\u00f3ria interna",
#                     "value_id": "84611",
#                     "value_name": "128 GB"
#                 },
#                 {
#                     "id": "RAM",
#                     "name": "Mem\u00f3ria RAM",
#                     "value_id": "579564",
#                     "value_name": "8 GB"
#                 },
#                 {
#                     "id": "MAIN_COLOR",
#                     "name": "Cor principal",
#                     "value_id": "11282035",
#                     "value_name": "Cinza-claro"
#                 },
#                 {
#                     "id": "SIM_CARD_SLOTS_NUMBER",
#                     "name": "Quantidade de ranhuras para cart\u00e3o SIM",
#                     "value_id": "2087812",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "OPERATING_SYSTEM_NAME",
#                     "name": "Nome do sistema operacional",
#                     "value_id": "7403813",
#                     "value_name": "Android"
#                 },
#                 {
#                     "id": "MOBILE_NETWORK",
#                     "name": "Rede m\u00f3vel",
#                     "value_id": "7472027",
#                     "value_name": "5G"
#                 },
#                 {
#                     "id": "PROCESSOR_MODEL",
#                     "name": "Modelo do processador",
#                     "value_id": "18543163",
#                     "value_name": "Octa Core"
#                 },
#                 {
#                     "id": "MANUFACTURER",
#                     "name": "Fabricante",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "CELLPHONES_ANATEL_HOMOLOGATION_NUMBER",
#                     "name": "N\u00famero de homologa\u00e7\u00e3o da Anatel",
#                     "value_id": "48639515",
#                     "value_name": "107622400953"
#                 }
#             ],
#             "pictures": [
#                 {
#                     "id": "883415-MLA83705856774_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_883415-MLA83705856774_042025-F.jpg"
#                 }
#             ],
#             "parent_id": "MLB48925518",
#             "children_ids": [],
#             "quality_type": "COMPLETE",
#             "priority": "MEDIUM",
#             "last_updated": "2025-10-21T10:26:11Z",
#             "type": "PRODUCT",
#             "keywords": "Celular Samsung Galaxy A56 128gb 8 Ram Grey",
#             "site_id": "MLB",
#             "variations": [],
#             "buying_mode": "",
#             "channels": [],
#             "description": ""
#         },
#         {
#             "id": "MLB47110137",
#             "date_created": "2025-03-13T18:39:58Z",
#             "catalog_product_id": "MLB47110137",
#             "pdp_types": [],
#             "status": "active",
#             "domain_id": "MLB-CELLPHONES",
#             "settings": {
#                 "listing_strategy": "catalog_required",
#                 "exclusive": false,
#                 "content": "fixed"
#             },
#             "name": "Samsung Galaxy A56 5g 128gb 8gb Ram Verde",
#             "main_features": [],
#             "attributes": [
#                 {
#                     "id": "BRAND",
#                     "name": "Marca",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "LINE",
#                     "name": "Linha",
#                     "value_id": "322977",
#                     "value_name": "Galaxy A"
#                 },
#                 {
#                     "id": "MODEL",
#                     "name": "Modelo",
#                     "value_id": "38463808",
#                     "value_name": "A56 5G"
#                 },
#                 {
#                     "id": "IS_DUAL_SIM",
#                     "name": "\u00c9 Dual SIM",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "COLOR",
#                     "name": "Cor",
#                     "value_id": "52014",
#                     "value_name": "Verde"
#                 },
#                 {
#                     "id": "INTERNAL_MEMORY",
#                     "name": "Mem\u00f3ria interna",
#                     "value_id": "84611",
#                     "value_name": "128 GB"
#                 },
#                 {
#                     "id": "RAM",
#                     "name": "Mem\u00f3ria RAM",
#                     "value_id": "579564",
#                     "value_name": "8 GB"
#                 },
#                 {
#                     "id": "SIM_CARD_SLOTS_NUMBER",
#                     "name": "Quantidade de ranhuras para cart\u00e3o SIM",
#                     "value_id": "2087812",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "ESIMS_NUMBER",
#                     "name": "Quantidade de eSIMs",
#                     "value_id": "8278380",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "OPERATING_SYSTEM_NAME",
#                     "name": "Nome do sistema operacional",
#                     "value_id": "7403813",
#                     "value_name": "Android"
#                 },
#                 {
#                     "id": "MOBILE_NETWORK",
#                     "name": "Rede m\u00f3vel",
#                     "value_id": "7472027",
#                     "value_name": "5G"
#                 },
#                 {
#                     "id": "PROCESSOR_MODEL",
#                     "name": "Modelo do processador",
#                     "value_id": "19270414",
#                     "value_name": "OCTA-CORE"
#                 },
#                 {
#                     "id": "PROCESSOR_SPEED",
#                     "name": "Velocidade do processador",
#                     "value_id": "7883188",
#                     "value_name": "2.9 GHz"
#                 },
#                 {
#                     "id": "MANUFACTURER",
#                     "name": "Fabricante",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "IS_GAMING_CELLPHONE",
#                     "name": "\u00c9 celular para jogos",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "IS_RUGGED_CELLPHONE",
#                     "name": "\u00c9 celular robusto",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "CELLPHONES_ANATEL_HOMOLOGATION_NUMBER",
#                     "name": "N\u00famero de homologa\u00e7\u00e3o da Anatel",
#                     "value_id": "48639515",
#                     "value_name": "107622400953"
#                 },
#                 {
#                     "id": "ALPHANUMERIC_MODELS",
#                     "name": "Modelo alfanum\u00e9rico",
#                     "value_name": "SMA556DS"
#                 },
#                 {
#                     "id": "OS_LAST_COMPATIBLE_VERSION",
#                     "name": "\u00daltima vers\u00e3o compat\u00edvel do sistema operacional",
#                     "value_id": "11104001",
#                     "value_name": "15"
#                 },
#                 {
#                     "id": "DISPLAY_SIZE",
#                     "name": "Tamanho da tela",
#                     "value_id": "7174581",
#                     "value_name": "6.7 \""
#                 },
#                 {
#                     "id": "DISPLAY_RESOLUTION_TYPE",
#                     "name": "Tipo de resolu\u00e7\u00e3o da tela",
#                     "value_id": "9568930",
#                     "value_name": "Full HD+"
#                 },
#                 {
#                     "id": "DISPLAY_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da tela",
#                     "value_id": "7209646",
#                     "value_name": "1080 px x 2340 px"
#                 },
#                 {
#                     "id": "MAIN_REAR_CAMERA_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da c\u00e2mera traseira principal",
#                     "value_id": "8232281",
#                     "value_name": "50 Mpx"
#                 },
#                 {
#                     "id": "REAR_CAMERA_RECORDING_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o de v\u00eddeo da c\u00e2mera traseira",
#                     "value_id": "7199630",
#                     "value_name": "3840 px x 2160 px"
#                 },
#                 {
#                     "id": "MAIN_FRONT_CAMERA_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da c\u00e2mera frontal principal",
#                     "value_id": "7207109",
#                     "value_name": "12 Mpx"
#                 },
#                 {
#                     "id": "WIDE_ANGLE_CAMERA_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da c\u00e2mera grande-angular",
#                     "value_id": "13216865",
#                     "value_name": "50 Mpx"
#                 },
#                 {
#                     "id": "BATTERY_CAPACITY",
#                     "name": "Capacidade da bateria",
#                     "value_id": "2896218",
#                     "value_name": "5 Ah"
#                 },
#                 {
#                     "id": "WITH_FINGERPRINT_READER",
#                     "name": "Com leitor de impress\u00e3o digital",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FACIAL_RECOGNITION",
#                     "name": "Com reconhecimento facial",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "INCLUDES_PENCIL",
#                     "name": "Inclui l\u00e1pis",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "COMPATIBLE_SIM_CARD_SIZES",
#                     "name": "Tamanhos de cart\u00e3o SIM compat\u00edveis",
#                     "value_name": "Nano-SIM"
#                 },
#                 {
#                     "id": "DISPLAY_TECHNOLOGY",
#                     "name": "Tecnologia da tela",
#                     "value_id": "80493",
#                     "value_name": "Super AMOLED"
#                 },
#                 {
#                     "id": "DISPLAY_TYPE",
#                     "name": "Tipo de tela",
#                     "value_id": "15306632",
#                     "value_name": "Super AMOLED"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_TYPES",
#                     "name": "Tipos de c\u00e2meras traseiras",
#                     "value_name": "Grande-angular"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o das c\u00e2meras traseiras",
#                     "value_id": "18465275",
#                     "value_name": "50 Mpx/12 Mpx/5 Mpx"
#                 },
#                 {
#                     "id": "FRONT_CAMERAS_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o das c\u00e2meras frontais",
#                     "value_name": "12 Mpx"
#                 },
#                 {
#                     "id": "IP_RATING",
#                     "name": "Classifica\u00e7\u00e3o IP",
#                     "value_id": "8275375",
#                     "value_name": "IP67"
#                 },
#                 {
#                     "id": "CHARGE_CONNECTOR_TYPE",
#                     "name": "Tipo de conector de carregamento",
#                     "value_id": "8275367",
#                     "value_name": "USB-C"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_NUMBER",
#                     "name": "Quantidade de c\u00e2meras traseiras",
#                     "value_id": "7505949",
#                     "value_name": "3"
#                 },
#                 {
#                     "id": "FRONT_CAMERAS_NUMBER",
#                     "name": "Quantidade de c\u00e2meras frontais",
#                     "value_id": "7477216",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "WEIGHT",
#                     "name": "Peso",
#                     "value_id": "2169027",
#                     "value_name": "198 g"
#                 },
#                 {
#                     "id": "HEIGHT",
#                     "name": "Altura",
#                     "value_id": "12983478",
#                     "value_name": "16.22 cm"
#                 },
#                 {
#                     "id": "WIDTH",
#                     "name": "Largura",
#                     "value_id": "5017530",
#                     "value_name": "7.75 cm"
#                 },
#                 {
#                     "id": "DEPTH",
#                     "name": "Profundidade",
#                     "value_id": "6912816",
#                     "value_name": "7.4 mm"
#                 },
#                 {
#                     "id": "DISPLAY_REFRESH_RATE",
#                     "name": "Taxa de atualiza\u00e7\u00e3o da tela",
#                     "value_id": "7875467",
#                     "value_name": "120 Hz"
#                 },
#                 {
#                     "id": "DIGITAL_ZOOM",
#                     "name": "Zoom digital",
#                     "value_id": "7199637",
#                     "value_name": "10x"
#                 },
#                 {
#                     "id": "WITH_ESIM",
#                     "name": "Com eSIM",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_TOUCHSCREEN_DISPLAY",
#                     "name": "Com tela t\u00e1til",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FOLDABLE_DISPLAY",
#                     "name": "Com tela dobr\u00e1vel",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_PHYSICAL_QWERTY_KEYBOARD",
#                     "name": "Com teclado QWERTY f\u00edsico",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_CAMERA",
#                     "name": "Com c\u00e2mera",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FRONT_CAMERA_FLASH",
#                     "name": "Com flash na c\u00e2mara frontal",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_USB_CONNECTOR",
#                     "name": "Com conector USB",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_WIFI",
#                     "name": "Com Wi-Fi",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_GPS",
#                     "name": "Com GPS",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_BLUETOOTH",
#                     "name": "Com Bluetooth",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_NFC",
#                     "name": "Com NFC",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_ACCELEROMETER",
#                     "name": "Com aceler\u00f4metro",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_PROXIMITY_SENSOR",
#                     "name": "Com sensor de proximidade",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_GYROSCOPE",
#                     "name": "Com girosc\u00f3pio",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "IS_WATER_RESISTANT",
#                     "name": "\u00c9 resistente \u00e0 \u00e1gua",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "IS_WATERPROOF",
#                     "name": "\u00c9 \u00e0 prova d'\u00e1gua",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "IS_DUST_RESISTANT",
#                     "name": "\u00c9 resistente ao p\u00f3",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "IS_DROP_RESISTANT",
#                     "name": "\u00c9 resistente a quedas",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FAST_CHARGING",
#                     "name": "Com carregamento r\u00e1pido",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_REMOVABLE_BATTERY",
#                     "name": "Com bateria remov\u00edvel",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 }
#             ],
#             "pictures": [
#                 {
#                     "id": "941044-MLA95238191379_102025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_941044-MLA95238191379_102025-F.jpg"
#                 },
#                 {
#                     "id": "855125-MLA93499466565_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_855125-MLA93499466565_092025-F.jpg"
#                 },
#                 {
#                     "id": "676172-MLA93499446643_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_676172-MLA93499446643_092025-F.jpg"
#                 },
#                 {
#                     "id": "630696-MLA93083525882_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_630696-MLA93083525882_092025-F.jpg"
#                 },
#                 {
#                     "id": "637952-MLA93499446685_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_637952-MLA93499446685_092025-F.jpg"
#                 },
#                 {
#                     "id": "751543-MLA93499446697_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_751543-MLA93499446697_092025-F.jpg"
#                 },
#                 {
#                     "id": "637847-MLA93083476718_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_637847-MLA93083476718_092025-F.jpg"
#                 },
#                 {
#                     "id": "874464-MLA93499164019_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_874464-MLA93499164019_092025-F.jpg"
#                 },
#                 {
#                     "id": "964158-MLA93083525948_092025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_964158-MLA93083525948_092025-F.jpg"
#                 }
#             ],
#             "parent_id": "MLB47104346",
#             "children_ids": [],
#             "quality_type": "COMPLETE",
#             "priority": "MEDIUM",
#             "last_updated": "2025-10-21T14:15:33Z",
#             "type": "PRODUCT",
#             "keywords": "Samsung Galaxy A56 5g 128gb 8gb Ram Verde",
#             "site_id": "MLB",
#             "variations": [],
#             "buying_mode": "",
#             "channels": [],
#             "description": ""
#         },
#         {
#             "id": "MLB48925521",
#             "date_created": "2025-04-23T14:06:52Z",
#             "catalog_product_id": "MLB48925521",
#             "pdp_types": [],
#             "status": "active",
#             "domain_id": "MLB-CELLPHONES",
#             "settings": {
#                 "listing_strategy": "catalog_required",
#                 "exclusive": false,
#                 "content": "fixed"
#             },
#             "name": "Samsung Galaxy A56 128 GB 8 RAM Verde",
#             "main_features": [],
#             "attributes": [
#                 {
#                     "id": "BRAND",
#                     "name": "Marca",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "LINE",
#                     "name": "Linha",
#                     "value_id": "322977",
#                     "value_name": "Galaxy A"
#                 },
#                 {
#                     "id": "MODEL",
#                     "name": "Modelo",
#                     "value_id": "28156286",
#                     "value_name": "A56"
#                 },
#                 {
#                     "id": "IS_DUAL_SIM",
#                     "name": "\u00c9 Dual SIM",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "COLOR",
#                     "name": "Cor",
#                     "value_id": "52015",
#                     "value_name": "Verde-claro"
#                 },
#                 {
#                     "id": "INTERNAL_MEMORY",
#                     "name": "Mem\u00f3ria interna",
#                     "value_id": "84611",
#                     "value_name": "128 GB"
#                 },
#                 {
#                     "id": "RAM",
#                     "name": "Mem\u00f3ria RAM",
#                     "value_id": "579564",
#                     "value_name": "8 GB"
#                 },
#                 {
#                     "id": "MAIN_COLOR",
#                     "name": "Cor principal",
#                     "value_id": "2450314",
#                     "value_name": "Verde"
#                 },
#                 {
#                     "id": "SIM_CARD_SLOTS_NUMBER",
#                     "name": "Quantidade de ranhuras para cart\u00e3o SIM",
#                     "value_id": "2087812",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "OPERATING_SYSTEM_NAME",
#                     "name": "Nome do sistema operacional",
#                     "value_id": "7403813",
#                     "value_name": "Android"
#                 },
#                 {
#                     "id": "MOBILE_NETWORK",
#                     "name": "Rede m\u00f3vel",
#                     "value_id": "7472027",
#                     "value_name": "5G"
#                 },
#                 {
#                     "id": "PROCESSOR_MODEL",
#                     "name": "Modelo do processador",
#                     "value_id": "18543163",
#                     "value_name": "Octa Core"
#                 },
#                 {
#                     "id": "MANUFACTURER",
#                     "name": "Fabricante",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "CELLPHONES_ANATEL_HOMOLOGATION_NUMBER",
#                     "name": "N\u00famero de homologa\u00e7\u00e3o da Anatel",
#                     "value_id": "48639515",
#                     "value_name": "107622400953"
#                 }
#             ],
#             "pictures": [
#                 {
#                     "id": "838946-MLA83995138763_042025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_838946-MLA83995138763_042025-F.jpg"
#                 }
#             ],
#             "parent_id": "MLB48925518",
#             "children_ids": [],
#             "quality_type": "COMPLETE",
#             "priority": "MEDIUM",
#             "last_updated": "2025-10-21T13:39:40Z",
#             "type": "PRODUCT",
#             "keywords": "Samsung Galaxy A56 128 GB 8 RAM Verde",
#             "site_id": "MLB",
#             "variations": [],
#             "buying_mode": "",
#             "channels": [],
#             "description": ""
#         },
#         {
#             "id": "MLB47115122",
#             "date_created": "2025-03-13T20:47:38Z",
#             "catalog_product_id": "MLB47115122",
#             "pdp_types": [],
#             "status": "active",
#             "domain_id": "MLB-CELLPHONES",
#             "settings": {
#                 "listing_strategy": "catalog_required",
#                 "exclusive": false,
#                 "content": "fixed"
#             },
#             "name": "Celular Samsung Galaxy A56 5g 128gb 8gb Ram Cinza",
#             "main_features": [],
#             "attributes": [
#                 {
#                     "id": "BRAND",
#                     "name": "Marca",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "LINE",
#                     "name": "Linha",
#                     "value_id": "322977",
#                     "value_name": "Galaxy A"
#                 },
#                 {
#                     "id": "MODEL",
#                     "name": "Modelo",
#                     "value_id": "38463808",
#                     "value_name": "A56 5G"
#                 },
#                 {
#                     "id": "IS_DUAL_SIM",
#                     "name": "\u00c9 Dual SIM",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "COLOR",
#                     "name": "Cor",
#                     "value_id": "283165",
#                     "value_name": "Cinza"
#                 },
#                 {
#                     "id": "INTERNAL_MEMORY",
#                     "name": "Mem\u00f3ria interna",
#                     "value_id": "84611",
#                     "value_name": "128 GB"
#                 },
#                 {
#                     "id": "RAM",
#                     "name": "Mem\u00f3ria RAM",
#                     "value_id": "579564",
#                     "value_name": "8 GB"
#                 },
#                 {
#                     "id": "SIM_CARD_SLOTS_NUMBER",
#                     "name": "Quantidade de ranhuras para cart\u00e3o SIM",
#                     "value_id": "2087812",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "ESIMS_NUMBER",
#                     "name": "Quantidade de eSIMs",
#                     "value_id": "8278380",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "OPERATING_SYSTEM_NAME",
#                     "name": "Nome do sistema operacional",
#                     "value_id": "7403813",
#                     "value_name": "Android"
#                 },
#                 {
#                     "id": "MOBILE_NETWORK",
#                     "name": "Rede m\u00f3vel",
#                     "value_id": "7472027",
#                     "value_name": "5G"
#                 },
#                 {
#                     "id": "PROCESSOR_MODEL",
#                     "name": "Modelo do processador",
#                     "value_id": "19270414",
#                     "value_name": "OCTA-CORE"
#                 },
#                 {
#                     "id": "PROCESSOR_SPEED",
#                     "name": "Velocidade do processador",
#                     "value_id": "7883188",
#                     "value_name": "2.9 GHz"
#                 },
#                 {
#                     "id": "MANUFACTURER",
#                     "name": "Fabricante",
#                     "value_id": "206",
#                     "value_name": "Samsung"
#                 },
#                 {
#                     "id": "IS_GAMING_CELLPHONE",
#                     "name": "\u00c9 celular para jogos",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "IS_RUGGED_CELLPHONE",
#                     "name": "\u00c9 celular robusto",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "CELLPHONES_ANATEL_HOMOLOGATION_NUMBER",
#                     "name": "N\u00famero de homologa\u00e7\u00e3o da Anatel",
#                     "value_id": "48639515",
#                     "value_name": "107622400953"
#                 },
#                 {
#                     "id": "ALPHANUMERIC_MODELS",
#                     "name": "Modelo alfanum\u00e9rico",
#                     "value_name": "SMA556DS"
#                 },
#                 {
#                     "id": "OS_LAST_COMPATIBLE_VERSION",
#                     "name": "\u00daltima vers\u00e3o compat\u00edvel do sistema operacional",
#                     "value_id": "11104001",
#                     "value_name": "15"
#                 },
#                 {
#                     "id": "DISPLAY_SIZE",
#                     "name": "Tamanho da tela",
#                     "value_id": "7174581",
#                     "value_name": "6.7 \""
#                 },
#                 {
#                     "id": "DISPLAY_RESOLUTION_TYPE",
#                     "name": "Tipo de resolu\u00e7\u00e3o da tela",
#                     "value_id": "9568930",
#                     "value_name": "Full HD+"
#                 },
#                 {
#                     "id": "DISPLAY_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da tela",
#                     "value_id": "7209646",
#                     "value_name": "1080 px x 2340 px"
#                 },
#                 {
#                     "id": "MAIN_REAR_CAMERA_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da c\u00e2mera traseira principal",
#                     "value_id": "8232281",
#                     "value_name": "50 Mpx"
#                 },
#                 {
#                     "id": "REAR_CAMERA_RECORDING_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o de v\u00eddeo da c\u00e2mera traseira",
#                     "value_id": "7199630",
#                     "value_name": "3840 px x 2160 px"
#                 },
#                 {
#                     "id": "MAIN_FRONT_CAMERA_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da c\u00e2mera frontal principal",
#                     "value_id": "7207109",
#                     "value_name": "12 Mpx"
#                 },
#                 {
#                     "id": "WIDE_ANGLE_CAMERA_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da c\u00e2mera grande-angular",
#                     "value_id": "13216865",
#                     "value_name": "50 Mpx"
#                 },
#                 {
#                     "id": "BATTERY_CAPACITY",
#                     "name": "Capacidade da bateria",
#                     "value_id": "2896218",
#                     "value_name": "5 Ah"
#                 },
#                 {
#                     "id": "WITH_FINGERPRINT_READER",
#                     "name": "Com leitor de impress\u00e3o digital",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FACIAL_RECOGNITION",
#                     "name": "Com reconhecimento facial",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "INCLUDES_PENCIL",
#                     "name": "Inclui l\u00e1pis",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "COMPATIBLE_SIM_CARD_SIZES",
#                     "name": "Tamanhos de cart\u00e3o SIM compat\u00edveis",
#                     "value_name": "Nano-SIM"
#                 },
#                 {
#                     "id": "DISPLAY_TECHNOLOGY",
#                     "name": "Tecnologia da tela",
#                     "value_id": "80493",
#                     "value_name": "Super AMOLED"
#                 },
#                 {
#                     "id": "DISPLAY_TYPE",
#                     "name": "Tipo de tela",
#                     "value_id": "15306632",
#                     "value_name": "Super AMOLED"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_TYPES",
#                     "name": "Tipos de c\u00e2meras traseiras",
#                     "value_name": "Grande-angular"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o das c\u00e2meras traseiras",
#                     "value_id": "18465275",
#                     "value_name": "50 Mpx/12 Mpx/5 Mpx"
#                 },
#                 {
#                     "id": "FRONT_CAMERAS_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o das c\u00e2meras frontais",
#                     "value_name": "12 Mpx"
#                 },
#                 {
#                     "id": "IP_RATING",
#                     "name": "Classifica\u00e7\u00e3o IP",
#                     "value_id": "8275375",
#                     "value_name": "IP67"
#                 },
#                 {
#                     "id": "CHARGE_CONNECTOR_TYPE",
#                     "name": "Tipo de conector de carregamento",
#                     "value_id": "8275367",
#                     "value_name": "USB-C"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_NUMBER",
#                     "name": "Quantidade de c\u00e2meras traseiras",
#                     "value_id": "7505949",
#                     "value_name": "3"
#                 },
#                 {
#                     "id": "FRONT_CAMERAS_NUMBER",
#                     "name": "Quantidade de c\u00e2meras frontais",
#                     "value_id": "7477216",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "WEIGHT",
#                     "name": "Peso",
#                     "value_id": "2169027",
#                     "value_name": "198 g"
#                 },
#                 {
#                     "id": "HEIGHT",
#                     "name": "Altura",
#                     "value_id": "12983478",
#                     "value_name": "16.22 cm"
#                 },
#                 {
#                     "id": "WIDTH",
#                     "name": "Largura",
#                     "value_id": "5017530",
#                     "value_name": "7.75 cm"
#                 },
#                 {
#                     "id": "DEPTH",
#                     "name": "Profundidade",
#                     "value_id": "6912816",
#                     "value_name": "7.4 mm"
#                 },
#                 {
#                     "id": "DISPLAY_REFRESH_RATE",
#                     "name": "Taxa de atualiza\u00e7\u00e3o da tela",
#                     "value_id": "7875467",
#                     "value_name": "120 Hz"
#                 },
#                 {
#                     "id": "DIGITAL_ZOOM",
#                     "name": "Zoom digital",
#                     "value_id": "7199637",
#                     "value_name": "10x"
#                 },
#                 {
#                     "id": "WITH_ESIM",
#                     "name": "Com eSIM",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_TOUCHSCREEN_DISPLAY",
#                     "name": "Com tela t\u00e1til",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FOLDABLE_DISPLAY",
#                     "name": "Com tela dobr\u00e1vel",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_PHYSICAL_QWERTY_KEYBOARD",
#                     "name": "Com teclado QWERTY f\u00edsico",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_CAMERA",
#                     "name": "Com c\u00e2mera",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FRONT_CAMERA_FLASH",
#                     "name": "Com flash na c\u00e2mara frontal",
#                     "value_id": "242084",
# ...
#                     "name": "Resolu\u00e7\u00e3o de v\u00eddeo da c\u00e2mera traseira",
#                     "value_id": "8075985",
#                     "value_name": "7680 px x 4320 px"
#                 },
#                 {
#                     "id": "MAIN_FRONT_CAMERA_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o da c\u00e2mera frontal principal",
#                     "value_id": "7222497",
#                     "value_name": "10 Mpx"
#                 },
#                 {
#                     "id": "BATTERY_CAPACITY",
#                     "name": "Capacidade da bateria",
#                     "value_id": "40036676",
#                     "value_name": "3.7 Ah"
#                 },
#                 {
#                     "id": "WITH_FINGERPRINT_READER",
#                     "name": "Com leitor de impress\u00e3o digital",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FACIAL_RECOGNITION",
#                     "name": "Com reconhecimento facial",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "INCLUDES_PENCIL",
#                     "name": "Inclui l\u00e1pis",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "VERSIONS",
#                     "name": "Vers\u00f5es",
#                     "value_name": "SM-S901U, SM-S901W, SM-S901U1, SM-S901E/DS, SM-S9010, SM-S901N"
#                 },
#                 {
#                     "id": "COMPATIBLE_SIM_CARD_SIZES",
#                     "name": "Tamanhos de cart\u00e3o SIM compat\u00edveis",
#                     "value_name": "Nano-SIM"
#                 },
#                 {
#                     "id": "OS_PERSONALIZATION_ORIGINAL_SHELL",
#                     "name": "Camada original de personaliza\u00e7\u00e3o do sistema operacional",
#                     "value_id": "11821919",
#                     "value_name": "One UI 4"
#                 },
#                 {
#                     "id": "RELEASE_MONTH",
#                     "name": "M\u00eas de lan\u00e7amento",
#                     "value_id": "8275341",
#                     "value_name": "Fevereiro"
#                 },
#                 {
#                     "id": "DISPLAY_TECHNOLOGY",
#                     "name": "Tecnologia da tela",
#                     "value_id": "8202723",
#                     "value_name": "Dynamic AMOLED 2X"
#                 },
#                 {
#                     "id": "DISPLAY_TYPE",
#                     "name": "Tipo de tela",
#                     "value_id": "9606643",
#                     "value_name": "Infinity-O Display"
#                 },
#                 {
#                     "id": "CAMERAS_MAIN_FEATURES",
#                     "name": "Caracter\u00edsticas principais das c\u00e2meras",
#                     "value_name": "Autoenfoque, Modo noite, Modo retrato, Panor\u00e2mica, Foto HDR"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o das c\u00e2meras traseiras",
#                     "value_id": "11765012",
#                     "value_name": "50 Mpx/12 Mpx/10 Mpx"
#                 },
#                 {
#                     "id": "REAR_CAMERA_APERTURE",
#                     "name": "Abertura do diafragma da c\u00e2mera traseira",
#                     "value_id": "11076396",
#                     "value_name": "f 2.4/f 2.2/f 1.8"
#                 },
#                 {
#                     "id": "FRONT_CAMERA_APERTURE",
#                     "name": "Abertura do diafragma da c\u00e2mera frontal",
#                     "value_id": "7408595",
#                     "value_name": "f 2.2"
#                 },
#                 {
#                     "id": "CPU_MODELS",
#                     "name": "Modelos de CPU",
#                     "value_name": "1x2.99 GHz Cortex-X2, 3x2.4 GHz Cortex-A710, 4x1.7 GHz Cortex-A510"
#                 },
#                 {
#                     "id": "GPU_MODEL",
#                     "name": "Modelo de GPU",
#                     "value_id": "11732851",
#                     "value_name": "Adreno 730"
#                 },
#                 {
#                     "id": "IP_RATING",
#                     "name": "Classifica\u00e7\u00e3o IP",
#                     "value_id": "8275373",
#                     "value_name": "IP68"
#                 },
#                 {
#                     "id": "BATTERY_TYPE",
#                     "name": "Tipo de bateria",
#                     "value_id": "95013",
#                     "value_name": "\u00cdon de l\u00edtio"
#                 },
#                 {
#                     "id": "CHARGE_CONNECTOR_TYPE",
#                     "name": "Tipo de conector de carregamento",
#                     "value_id": "8275367",
#                     "value_name": "USB-C"
#                 },
#                 {
#                     "id": "RELEASE_YEAR",
#                     "name": "Ano de lan\u00e7amento",
#                     "value_id": "11166326",
#                     "value_name": "2022"
#                 },
#                 {
#                     "id": "REAR_CAMERAS_NUMBER",
#                     "name": "Quantidade de c\u00e2meras traseiras",
#                     "value_id": "7505949",
#                     "value_name": "3"
#                 },
#                 {
#                     "id": "FRONT_CAMERAS_NUMBER",
#                     "name": "Quantidade de c\u00e2meras frontais",
#                     "value_id": "7477216",
#                     "value_name": "1"
#                 },
#                 {
#                     "id": "PROCESSOR_CORES_NUMBER",
#                     "name": "Quantidade de n\u00facleos do processador",
#                     "value_id": "7206961",
#                     "value_name": "8"
#                 },
#                 {
#                     "id": "WEIGHT",
#                     "name": "Peso",
#                     "value_id": "2087871",
#                     "value_name": "167 g"
#                 },
#                 {
#                     "id": "HEIGHT",
#                     "name": "Altura",
#                     "value_id": "6971110",
#                     "value_name": "14.6 cm"
#                 },
#                 {
#                     "id": "WIDTH",
#                     "name": "Largura",
#                     "value_id": "46335601",
#                     "value_name": "7.06 cm"
#                 },
#                 {
#                     "id": "DEPTH",
#                     "name": "Profundidade",
#                     "value_id": "6858412",
#                     "value_name": "7.6 mm"
#                 },
#                 {
#                     "id": "DISPLAY_PIXELS_PER_INCH",
#                     "name": "Pixels por polegada da tela",
#                     "value_id": "8147954",
#                     "value_name": "425 ppi"
#                 },
#                 {
#                     "id": "DISPLAY_REFRESH_RATE",
#                     "name": "Taxa de atualiza\u00e7\u00e3o da tela",
#                     "value_id": "7875467",
#                     "value_name": "120 Hz"
#                 },
#                 {
#                     "id": "MAX_DISPLAY_BRIGHTNESS",
#                     "name": "Brilho m\u00e1ximo da tela",
#                     "value_id": "8435408",
#                     "value_name": "1300 cd/m\u00b2"
#                 },
#                 {
#                     "id": "OPTICAL_ZOOM",
#                     "name": "Zoom \u00f3ptico",
#                     "value_id": "960",
#                     "value_name": "3x"
#                 },
#                 {
#                     "id": "DIGITAL_ZOOM",
#                     "name": "Zoom digital",
#                     "value_id": "7865788",
#                     "value_name": "30x"
#                 },
#                 {
#                     "id": "TALK_TIME",
#                     "name": "Autonomia de conversa\u00e7\u00e3o",
#                     "value_id": "6973758",
#                     "value_name": "33 h"
#                 },
#                 {
#                     "id": "FRONT_CAMERA_RECORDING_RESOLUTION",
#                     "name": "Resolu\u00e7\u00e3o de v\u00eddeo da c\u00e2mera frontal",
#                     "value_id": "7207112",
#                     "value_name": "3840 px x 2160 px"
#                 },
#                 {
#                     "id": "DISPLAY_ASPECT_RATIO",
#                     "name": "Propor\u00e7\u00e3o da tela",
#                     "value_id": "11331351",
#                     "value_name": "19.5:9"
#                 },
#                 {
#                     "id": "WITH_ESIM",
#                     "name": "Com eSIM",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_TOUCHSCREEN_DISPLAY",
#                     "name": "Com tela t\u00e1til",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FOLDABLE_DISPLAY",
#                     "name": "Com tela dobr\u00e1vel",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_PHYSICAL_QWERTY_KEYBOARD",
#                     "name": "Com teclado QWERTY f\u00edsico",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_CAMERA",
#                     "name": "Com c\u00e2mera",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FRONT_CAMERA_FLASH",
#                     "name": "Com flash na c\u00e2mara frontal",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_MEMORY_CARD_SLOT",
#                     "name": "Com ranhura para cart\u00e3o de mem\u00f3ria",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_USB_CONNECTOR",
#                     "name": "Com conector USB",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_3_5_MM_JACK_CONNECTOR",
#                     "name": "Com conector jack 3.5 mm",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_WIFI",
#                     "name": "Com Wi-Fi",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_GPS",
#                     "name": "Com GPS",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_BLUETOOTH",
#                     "name": "Com Bluetooth",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_NFC",
#                     "name": "Com NFC",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_RADIO",
#                     "name": "Com radio",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_TV_TUNER",
#                     "name": "Com sintonizador de TV",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 },
#                 {
#                     "id": "WITH_ACCELEROMETER",
#                     "name": "Com aceler\u00f4metro",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_PROXIMITY_SENSOR",
#                     "name": "Com sensor de proximidade",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_GYROSCOPE",
#                     "name": "Com girosc\u00f3pio",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_COMPASS",
#                     "name": "Com b\u00fassola",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_BAROMETER",
#                     "name": "Com bar\u00f4metro",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "IS_WATERPROOF",
#                     "name": "\u00c9 \u00e0 prova d'\u00e1gua",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "IS_DUST_RESISTANT",
#                     "name": "\u00c9 resistente ao p\u00f3",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "IS_DROP_RESISTANT",
#                     "name": "\u00c9 resistente a quedas",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_FAST_CHARGING",
#                     "name": "Com carregamento r\u00e1pido",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_WIRELESS_CHARGING",
#                     "name": "Com carregamento sem fio",
#                     "value_id": "242085",
#                     "value_name": "Sim"
#                 },
#                 {
#                     "id": "WITH_REMOVABLE_BATTERY",
#                     "name": "Com bateria remov\u00edvel",
#                     "value_id": "242084",
#                     "value_name": "N\u00e3o"
#                 }
#             ],
#             "pictures": [
#                 {
#                     "id": "816680-MLA95246629935_102025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_816680-MLA95246629935_102025-F.jpg"
#                 },
#                 {
#                     "id": "858484-MLA94469133905_102025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_858484-MLA94469133905_102025-F.jpg"
#                 },
#                 {
#                     "id": "731019-MLA94469183451_102025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_731019-MLA94469183451_102025-F.jpg"
#                 },
#                 {
#                     "id": "808193-MLA94469232683_102025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_808193-MLA94469232683_102025-F.jpg"
#                 },
#                 {
#                     "id": "782036-MLA94469252577_102025",
#                     "url": "https://http2.mlstatic.com/D_NQ_NP_782036-MLA94469252577_102025-F.jpg"
#                 }
#             ],
#             "parent_id": "MLB18967698",
#             "children_ids": [],
#             "quality_type": "COMPLETE",
#             "priority": "MEDIUM",
#             "last_updated": "2025-10-21T14:15:38Z",
#             "type": "PRODUCT",
#             "keywords": "Samsung Galaxy S22 5g 128gb 8gb Ram Branco",
#             "site_id": "MLB",
#             "variations": [],
#             "buying_mode": "",
#             "channels": [],
#             "description": ""
#         }
#     ],
#     "used_attributes": [
#         {
#             "id": "BRAND",
#             "name": "Marca",
#             "value_id": "206",
#             "value_name": "Samsung"
#         }
#     ],
#     "query_type": "PRODUCT_NAME"
# }

# %%
products_df = pd.DataFrame(products_data['results'])
products_df
# Out:
#               id          date_created catalog_product_id pdp_types  status  \
# 0    MLB52144330  2025-07-08T22:52:06Z        MLB52144330        []  active
# 1    MLB48925520  2025-04-23T14:06:49Z        MLB48925520        []  active
# 2    MLB48927251  2025-04-23T17:26:54Z        MLB48927251        []  active
# 3    MLB47110137  2025-03-13T18:39:58Z        MLB47110137        []  active
# 4    MLB48925521  2025-04-23T14:06:52Z        MLB48925521        []  active
# ..           ...                   ...                ...       ...     ...
# 195  MLB36484947  2024-05-02T14:18:29Z        MLB36484947        []  active
# 196  MLB45523091  2025-01-16T17:53:37Z        MLB45523091        []  active
# 197  MLB44661685  2024-12-10T12:53:53Z        MLB44661685        []  active
# 198  MLB47639920  2025-04-01T19:48:59Z        MLB47639920        []  active
# 199  MLB18967701  2022-03-10T22:03:58Z        MLB18967701        []  active
#
#           domain_id                                           settings  \
# 0    MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 1    MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 2    MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 3    MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 4    MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# ..              ...                                                ...
# 195  MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 196  MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 197  MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 198  MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
# 199  MLB-CELLPHONES  {'listing_strategy': 'catalog_required', 'excl...
#
#                                                   name main_features  \
# 0                 Samsung Galaxy A56 128gb 8 RAM preto            []
# 1                  Samsung Galaxy A56 128gb 8 RAM rosa            []
# 2          Celular Samsung Galaxy A56 128gb 8 Ram Grey            []
# 3            Samsung Galaxy A56 5g 128gb 8gb Ram Verde            []
# 4                Samsung Galaxy A56 128 GB 8 RAM Verde            []
# ..                                                 ...           ...
# 195          Samsung Galaxy A14 5G 128gb preto 4gb RAM            []
# 196  Samsung Galaxy S25+ 512GB, 12GB, Câmera Tripla...            []
# 197   Samsung Galaxy S10 Plus Placa Queimada Cor Preto            []
# 198               Samsung Galaxy Z Flip 4 256 Gb Preto            []
# 199         Samsung Galaxy S22 5g 128gb 8gb Ram Branco            []
#
#                                             attributes  ... quality_type  \
# 0    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 1    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 2    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 3    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 4    [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# ..                                                 ...  ...          ...
# 195  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 196  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 197  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 198  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
# 199  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...  ...     COMPLETE
#
#     priority          last_updated     type  \
# 0     MEDIUM  2025-10-21T11:40:37Z  PRODUCT
# 1     MEDIUM  2025-10-21T12:17:50Z  PRODUCT
# 2     MEDIUM  2025-10-21T10:26:11Z  PRODUCT
# 3     MEDIUM  2025-10-21T14:15:33Z  PRODUCT
# 4     MEDIUM  2025-10-21T13:39:40Z  PRODUCT
# ..       ...                   ...      ...
# 195   MEDIUM  2025-10-21T11:35:34Z  PRODUCT
# 196   MEDIUM  2025-10-21T10:54:53Z  PRODUCT
# 197   MEDIUM  2025-10-21T09:27:21Z  PRODUCT
# 198   MEDIUM  2025-10-21T13:51:07Z  PRODUCT
# 199   MEDIUM  2025-10-21T14:15:38Z  PRODUCT
#
#                                               keywords site_id variations  \
# 0                 Samsung Galaxy A56 128gb 8 RAM preto     MLB         []
# 1                  Samsung Galaxy A56 128gb 8 RAM rosa     MLB         []
# 2          Celular Samsung Galaxy A56 128gb 8 Ram Grey     MLB         []
# 3            Samsung Galaxy A56 5g 128gb 8gb Ram Verde     MLB         []
# 4                Samsung Galaxy A56 128 GB 8 RAM Verde     MLB         []
# ..                                                 ...     ...        ...
# 195          Samsung Galaxy A14 5G 128gb preto 4gb RAM     MLB         []
# 196  Samsung Galaxy S25+ 512GB, 12GB, Câmera Tripla...     MLB         []
# 197   Samsung Galaxy S10 Plus Placa Queimada Cor Preto     MLB         []
# 198               Samsung Galaxy Z Flip 4 256 Gb Preto     MLB         []
# 199         Samsung Galaxy S22 5g 128gb 8gb Ram Branco     MLB         []
#
#     buying_mode channels description
# 0                     []
# 1                     []
# 2                     []
# 3                     []
# 4                     []
# ..          ...      ...         ...
# 195                   []
# 196                   []
# 197                   []
# 198                   []
# 199                   []
#
# [200 rows x 23 columns]

# %% [markdown]
# ## Get items
